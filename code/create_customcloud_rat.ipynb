# %% [markdown]
# ## Custom selection for visualising 3D point clouds (rat)
#
# This script allows you to create custom 3D point clouds of tracer data for the visualization in Meshview.
#
# The script needs to be placed on level above the subject folder (if you download the dataset as it is, the script is in the correct location).
#
# You can choose cases from 4 rat datasets:
# 1. [rat cortex](https://doi.org/10.25493/9TMN-64U)
# 2. [rat somatosensory cortex](https://doi.org/10.25493/ZSZ9-3NN)
# 3. [rat barrel cortex](https://doi.org/10.25493/W8MG-X2R)
# 4. [rat sensorimotor cortex](https://doi.org/10.25493/TH1N-V8P)
#
# Once you have defined the region of interest and the experiments you want to visualize the data of, a custom made JSON file will be created with this relevant information. You can visualize these to [Meshview](https://meshview.apps.hbp.eu/?atlas=WHS_SD_Rat_v4_39um) via "Choose files".

# %%
# Import packages
import json
import os
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## Choose the datasets you are interested in
#
# Choose one or more of the following datasets:
# 1. rat cortex
# 2. rat somatosensory cortex
# 3. rat barrel cortex
# 4. rat sensorimotor cortex

# %%
# Choose datasets of interests
dataset_options = ["rat cortex", "rat somatosensory cortex", "rat barrel cortex", "rat sensorimotor cortex"]
listOfDatasets = []
while len(listOfDatasets) == 0:
    DOI = input("Which datasets do you want to create a custom cloud for? Choose a number between 1-4, for example: 1,2: \n")
    listOfDatasets = [int(i) for i in DOI.split(",")]

# Print the selected datasets
print("Selected datasets: \n")
for d in range(len(listOfDatasets)):
    dname = dataset_options[listOfDatasets[d]-1]
    print(f"{dname}\n")
# Out:
# Selected datasets:
#
# rat cortex
#
# rat somatosensory cortex

# %% [markdown]
# ## Load experiment details

# %%
# Data folder
data_folder = os.path.join("..", "data")

# Check if output folder exist, if not create the folder
output_folder = os.path.join("..", "output")
if not os.path.exists(output_folder):
   os.makedirs(output_folder)
   print("The new directory is created!")

sheetnames = ["Rat_cortex", "Rat_SS", "Rat_barrel", "Rat_SM"]
expInfo = pd.DataFrame()   
for d in  range(len(DOI.split(","))):
   sheetname = sheetnames[int(DOI.split(",")[d])-1]
   expInfo_temp = pd.read_excel(os.path.join("..", "ExpOverview.xlsx"), sheet_name=sheetname)

   expInfo = pd.concat([expInfo, expInfo_temp])

expInfo = expInfo.reset_index(drop=True)
expInfo["expNumber"] = [x+1 for x in expInfo.index.tolist()]

# %% [markdown]
# ### Please specify which experiment numbers you are interested in
#
# The list of available cases in the selected datasets are printed below. Select up to 10 different experiments and separate the numbers with a comma. The number of the case is given in the column "expNumber"

# %%
# Overview of all available cases in the selected dataset(s)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(expInfo)
# Out:
#     expNumber   expName        genotype     sex age_injection age_euthanisia  \
# 0           1  R401_Pha          wistar  female         adult          adult
# 1           2  R402_BDA          wistar    male         adult          adult
# 2           3  R403_BDA          wistar    male         adult          adult
# 3           4   R405_FG          wistar  female         adult          adult
# 4           5   R405_Fr          wistar  female         adult          adult
# 5           6   R406_FB  Sprague-Dawley  female         adult          adult
# 6           7   R406_Fe  Sprague-Dawley  female         adult          adult
# 7           8   R406_FG  Sprague-Dawley  female         adult          adult
# 8           9   R406_Fr  Sprague-Dawley  female         adult          adult
# 9          10   R407_Fe  Sprague-Dawley  female         adult          adult
# 10         11   R407_Fr  Sprague-Dawley  female         adult          adult
# 11         12   R409_Fr  Sprague-Dawley  female         adult          adult
# 12         13   R410_Fr  Sprague-Dawley  female         adult          adult
# 13         14  R411_BDA  Sprague-Dawley  female         adult          adult
# 14         15   R411_Fe  Sprague-Dawley  female         adult          adult
# 15         16   R411_Fr  Sprague-Dawley  female         adult          adult
# 16         17  R412_BDA  Sprague-Dawley  female         adult          adult
# 17         18   R412_Fe  Sprague-Dawley  female         adult          adult
# 18         19   R412_Fr  Sprague-Dawley  female         adult          adult
# 19         20  R413_BDA  Sprague-Dawley  female         adult          adult
# 20         21   R413_Fe  Sprague-Dawley  female         adult          adult
# 21         22   R413_Fr  Sprague-Dawley  female         adult          adult
# 22         23  R101_WGA  Sprague-Dawley  female         adult          adult
# 23         24  R102_BDA  Sprague-Dawley  female         adult          adult
# 24         25  R103_WGA  Sprague-Dawley  female         adult          adult
# 25         26  R105_WGA  Sprague-Dawley  female         adult          adult
# 26         27  R106_Pha  Sprague-Dawley  female         adult          adult
# 27         28  R109_Pha  Sprague-Dawley  female         adult          adult
# 28         29  R113_BDA  Sprague-Dawley  female         adult          adult
# 29         30  R115_BDA  Sprague-Dawley  female         adult          adult
# 30         31  R117_BDA  Sprague-Dawley  female         adult          adult
# 31         32  R118_BDA  Sprague-Dawley  female         adult          adult
# 32         33  R119_BDA  Sprague-Dawley  female         adult          adult
# 33         34  R120_BDA  Sprague-Dawley  female         adult          adult
# 34         35  R121_BDA  Sprague-Dawley  female         adult          adult
# 35         36   R121_Fr  Sprague-Dawley  female         adult          adult
# 36         37  R123_BDA  Sprague-Dawley  female         adult          adult
# 37         38  R124_BDA  Sprague-Dawley  female         adult          adult
#
#     injectionArea                                         regionFull  \
# 0           S1-fl  Primary somatosensory area, forelimb represent...
# 1              M2                               Secondary motor area
# 2              M2                               Secondary motor area
# 3           S1-hl  Primary somatosensory area, hindlimb represent...
# 4           S1-hl  Primary somatosensory area, hindlimb represent...
# 5              M1                                 Primary motor area
# 6            S1-f    Primary somatosensory area, face representation
# 7              M1                                 Primary motor area
# 8            S1-f    Primary somatosensory area, face representation
# 9   S1-fl / S1-hl  Primary somatosensory area, forelimb represent...
# 10          S1-fl  Primary somatosensory area, forelimb represent...
# 11             M2                               Secondary motor area
# 12             M2                               Secondary motor area
# 13             V1                                Primary visual area
# 14             V1                                Primary visual area
# 15             V1                                Primary visual area
# 16             V1                                Primary visual area
# 17            V2M                 Secondary visual area, medial part
# 18             V1                                Primary visual area
# 19             V1                                Primary visual area
# 20            V2L                                Primary visual area
# 21             V1                                Primary visual area
# 22             S1                         Primary somatosensory area
# 23             S1                         Primary somatosensory area
# 24           S1-f    Primary somatosensory area, face representation
# 25           S1-f    Primary somatosensory area, face representation
# 26           S1-f    Primary somatosensory area, face representation
# 27           S1-f    Primary somatosensory area, face representation
# 28           S1-f    Primary somatosensory area, face representation
# 29          S1-fl  Primary somatosensory area, forelimb represent...
# 30          S1-tr   Primary somatosensory area, trunk representation
# 31          S1-tr   Primary somatosensory area, trunk representation
# 32          S1-tr   Primary somatosensory area, trunk representation
# 33          S1-tr   Primary somatosensory area, trunk representation
# 34          S1-tr   Primary somatosensory area, trunk representation
# 35          S1-fl  Primary somatosensory area, forelimb represent...
# 36          S1-hl  Primary somatosensory area, hindlimb represent...
# 37          S1-hl  Primary somatosensory area, hindlimb represent...
#
#    injection_hemisphere colorName          RGB  gradient
# 0                  left     black     [0 0 0 ]       3.0
# 1                  left     black     [0 0 0 ]       3.0
# 2                  left     black     [0 0 0 ]       5.0
# 3                  left    yellow  [255 255 0]       4.0
# 4                  left       red    [255 0 0]       4.0
# 5                  left      blue    [0 0 255]       2.0
# 6                  left     green    [0 127 0]       2.0
# 7                  left    yellow  [255 255 0]       2.0
# 8                  left       red    [255 0 0]       2.0
# 9                  left     green    [0 127 0]       3.0
# 10                 left       red    [255 0 0]       3.0
# 11                 left       red    [255 0 0]       4.0
# 12                 left       red    [255 0 0]       3.0
# 13                 left     black     [0 0 0 ]       5.0
# 14                 left     green    [0 127 0]       4.0
# 15                 left       red    [255 0 0]       5.0
# 16                 left     black     [0 0 0 ]       6.0
# 17                 left     green    [0 127 0]       6.0
# 18                 left       red    [255 0 0]       6.0
# 19                 left     black     [0 0 0 ]       4.0
# 20                 left     green    [0 127 0]       3.0
# 21                 left       red    [255 0 0]       5.0
# 22                right     black      [0 0 0]       NaN
# 23                right     black      [0 0 0]       NaN
# 24                right     black      [0 0 0]       NaN
# 25                right     black      [0 0 0]       NaN
# 26                right     black      [0 0 0]       NaN
# 27                right     black      [0 0 0]       1.0
# 28                right     black      [0 0 0]       1.0
# 29                right     black      [0 0 0]       NaN
# 30                right     black      [0 0 0]       NaN
# 31                right     black      [0 0 0]       NaN
# 32                right     black      [0 0 0]       NaN
# 33                right     black      [0 0 0]       NaN
# 34                right     black      [0 0 0]       NaN
# 35                right       red    [255 0 0]       NaN
# 36                right     black      [0 0 0]       NaN
# 37                right     black      [0 0 0]       NaN

# %%
expInfo.expNumber.max()
# Out:
# 38

# %%
# Define which experiments you want to include
listOfExp = []
while len(listOfExp) == 0:
    EOI = input("Which experiment numbers are you interested in? Choose a number from the 'expNumber' column, for example: 1,3,6,16,18,20,34,37: \n")
    listOfExp = [int(i) for i in EOI.split(",")]

    if all(num < expInfo.expNumber.max() for num in listOfExp) == False:
        listOfExp = []
        print(f"Please only select number between 1 and {expInfo.expNumber.max()}")

    if len(EOI.split(",")) > 10:
        listOfExp = []
        print("Please only select 10 experiments. If necessary, create two custom files. Do not forget to change the file name")
print("Selected experiments: " + EOI + "\n")
# Out:
# Selected experiments: 1,3,6,16,18,20,34,37

# %% [markdown]
# Run the next cell to create a custom cloud for the experiments of interest. The output JSON file will be called: customCloud_Rat.json. If you want to change this, modify the cell below.
#
# Note: The point clouds are big files, so it may take up to 1 minute to compile.

# %%
filename = "customCloud_Rat.json"

# %% [markdown]
# To ensure that the point clouds can be differentiated from each other, we are setting the colors to the following.

# %%
# Colors
colors = [
    [139, 69, 19],      # brown
    [0, 128, 0],        # dark green
    [145, 162, 177],    # gray
    [75, 0, 130],       # purple
    [255, 0, 0],        # red
    [0, 255, 0],        # light green
    [0, 255, 255],      # cyan
    [0, 0, 255],        # dark blue
    [255, 255, 84],     # yellow
    [255, 105, 180],    # pink
    [255, 228, 196],    # beige
]

# %%
# Load the original JSON files and merge them into one custom cloud visualization.

# Using the list of experiment numbers, select a subset of the data
subset = expInfo.iloc[[int(index)-1 for index in listOfExp]].reset_index(drop=True)

points = []
points_list = {}
count = 0
for expName in subset.expName:
    fname = sorted(Path(data_folder).rglob(f"{expName}.json"))

    if len(fname) == 0:
        print(f"WARNING: File '{expName}.json' is not present in the data folder and is not included in the custom cloud. \nDownload the files from EBRAINS and place them in the data folder in this repository\n" )
    else:
        with open(fname[0], 'r') as f:
            points_list[expName] = json.load(f)
    
        cloud = points_list[expName][0]
        cloud['r'] = colors[count][0]
        cloud['g'] = colors[count][1]
        cloud['b'] = colors[count][2]

        points.append(cloud)
        count += 1

# Saving the JSON file
out_file = os.path.join(output_folder, filename)
print("Saving file " + out_file)
with open(out_file, 'w', encoding='utf-8') as fi:
    json.dump(points, fi, ensure_ascii=False)

print("Done!")
# Out:
# Saving file ..\output\customCloud_Rat.json
# Done!
